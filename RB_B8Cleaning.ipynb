# %% [markdown]
# <a href="https://colab.research.google.com/github/MahmoudSabryGithub/Digit-Classification/blob/main/RB_B8Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pandas import *
from numpy import *
import seaborn as sns
from matplotlib import pyplot as plt

# %%
data=read_csv("/RB-B8 - Copy.csv")

# %%
data.head()
# Out:
#              Timestamp  Status-Hz[Hz]  Press-Pump Intake (Pi)[psi]  \
# 0  05.01.2025 21:20:42            NaN                          NaN
# 1  05.01.2025 21:21:33           39.1                      2267.80
# 2  05.01.2025 21:22:38           39.1                      2268.00
# 3  05.01.2025 21:23:42           39.0                      2267.80
# 4  05.01.2025 21:24:51           38.9                      2264.79
#
#    Temp-Motor[degF]  Vib-Pump X axis[G]  Vib-Pump Y axis[G]  \
# 0               NaN                 NaN                 NaN
# 1             270.7               0.345               0.078
# 2             270.4               0.254               0.066
# 3             270.6               0.287               0.073
# 4             270.4               0.233               0.094
#
#    Press-Pump Discharge[psi]  Pwr-Motor Amps Ph B[A]  \
# 0                        NaN                     NaN
# 1                    3561.79                   43.16
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67189 entries, 0 to 67188
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Timestamp                    67189 non-null  object
#  1   Status-Hz[Hz]                19961 non-null  float64
#  2   Press-Pump Intake (Pi)[psi]  15976 non-null  float64
#  3   Temp-Motor[degF]             15893 non-null  float64
#  4   Vib-Pump X axis[G]           15810 non-null  float64
#  5   Vib-Pump Y axis[G]           15808 non-null  float64
#  6   Press-Pump Discharge[psi]    15928 non-null  float64
#  7   Pwr-Motor Amps Ph B[A]       19916 non-null  float64
#  8   Prod-Virtual % Water Cut[%]  5525 non-null   float64
#  9   Prod-Virtual GOR[SCF/STB]    5525 non-null   float64
#  10  Prod-Virtual Flow[BPD]       5533 non-null   float64
# dtypes: float64(10), object(1)
# memory usage: 5.6+ MB

# %%
Features=["Status-Hz[Hz]","Press-Pump Intake (Pi)[psi]","Temp-Motor[degF]"
,"Vib-Pump X axis[G]","Vib-Pump Y axis[G]","Press-Pump Discharge[psi]",
          "Pwr-Motor Amps Ph B[A]"]

# %%
data[Features]=data[Features].fillna(method='ffill')
# Out:
# <ipython-input-14-253f2f187f33>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data[Features]=data[Features].fillna(method='ffill')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67189 entries, 0 to 67188
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Timestamp                    67189 non-null  object
#  1   Status-Hz[Hz]                67188 non-null  float64
#  2   Press-Pump Intake (Pi)[psi]  67188 non-null  float64
#  3   Temp-Motor[degF]             67188 non-null  float64
#  4   Vib-Pump X axis[G]           67188 non-null  float64
#  5   Vib-Pump Y axis[G]           67188 non-null  float64
#  6   Press-Pump Discharge[psi]    67188 non-null  float64
#  7   Pwr-Motor Amps Ph B[A]       67188 non-null  float64
#  8   Prod-Virtual % Water Cut[%]  5525 non-null   float64
#  9   Prod-Virtual GOR[SCF/STB]    5525 non-null   float64
#  10  Prod-Virtual Flow[BPD]       5533 non-null   float64
# dtypes: float64(10), object(1)
# memory usage: 5.6+ MB

# %%
data["Prod-Virtual Flow[BPD]"].isnull().sum()
# Out:
# np.int64(61656)

# %%
data=data.dropna(subset=["Prod-Virtual Flow[BPD]"])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5533 entries, 0 to 64000
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Timestamp                    5533 non-null   object
#  1   Status-Hz[Hz]                5532 non-null   float64
#  2   Press-Pump Intake (Pi)[psi]  5532 non-null   float64
#  3   Temp-Motor[degF]             5532 non-null   float64
#  4   Vib-Pump X axis[G]           5532 non-null   float64
#  5   Vib-Pump Y axis[G]           5532 non-null   float64
#  6   Press-Pump Discharge[psi]    5532 non-null   float64
#  7   Pwr-Motor Amps Ph B[A]       5532 non-null   float64
#  8   Prod-Virtual % Water Cut[%]  5512 non-null   float64
#  9   Prod-Virtual GOR[SCF/STB]    5512 non-null   float64
#  10  Prod-Virtual Flow[BPD]       5533 non-null   float64
# dtypes: float64(10), object(1)
# memory usage: 518.7+ KB

# %%
data.to_csv("/content/RB-B8 - Copy1.csv")

# %%
data.head()
# Out:
#               Timestamp  Status-Hz[Hz]  Press-Pump Intake (Pi)[psi]  \
# 0   05.01.2025 21:20:42            NaN                          NaN
# 20  05.01.2025 21:40:42           39.1                      2268.90
# 38  05.01.2025 22:00:42           38.9                      2265.71
# 57  05.01.2025 22:20:42           38.9                      2266.90
# 76  05.01.2025 22:40:42           39.0                      2264.00
#
#     Temp-Motor[degF]  Vib-Pump X axis[G]  Vib-Pump Y axis[G]  \
# 0                NaN                 NaN                 NaN
# 20             270.4               0.254               0.074
# 38             270.5               0.296               0.072
# 57             270.4               0.247               0.073
# 76             270.4               0.275               0.094
#
#     Press-Pump Discharge[psi]  Pwr-Motor Amps Ph B[A]  \
# 0                         NaN                     NaN
# 20                    3559.99                   43.25
# ...

# %%
data.tail()
# Out:
#                  Timestamp  Status-Hz[Hz]  Press-Pump Intake (Pi)[psi]  \
# 63964  22.04.2025 23:16:57           42.0                       2029.0
# 63973  22.04.2025 23:36:57           42.0                       2029.0
# 63982  22.04.2025 23:56:57           42.0                       2030.0
# 63991  23.04.2025 00:16:57           42.0                       2029.0
# 64000  23.04.2025 00:36:57           42.0                       2029.0
#
#        Temp-Motor[degF]  Vib-Pump X axis[G]  Vib-Pump Y axis[G]  \
# 63964             272.0               0.210               0.105
# 63973             272.0               0.282               0.118
# 63982             272.0               0.242               0.098
# 63991             272.0               0.216               0.105
# 64000             272.0               0.210               0.105
#
#        Press-Pump Discharge[psi]  Pwr-Motor Amps Ph B[A]  \
# 63964                     3574.0                    41.6
# ...

# %%
data.drop(columns="Timestamp").corr()
# Out:
#                              Status-Hz[Hz]  Press-Pump Intake (Pi)[psi]  \
# Status-Hz[Hz]                     1.000000                    -0.669984
# Press-Pump Intake (Pi)[psi]      -0.669984                     1.000000
# Temp-Motor[degF]                  0.264748                    -0.107576
# Vib-Pump X axis[G]               -0.227355                     0.285843
# Vib-Pump Y axis[G]                0.053470                    -0.162797
# Press-Pump Discharge[psi]        -0.157407                     0.302304
# Pwr-Motor Amps Ph B[A]            0.118167                     0.430002
# Prod-Virtual % Water Cut[%]      -0.142684                     0.534612
# Prod-Virtual GOR[SCF/STB]         0.166766                    -0.281776
# Prod-Virtual Flow[BPD]            0.123807                     0.266296
#
#                              Temp-Motor[degF]  Vib-Pump X axis[G]  \
# Status-Hz[Hz]                        0.264748           -0.227355
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5533 entries, 0 to 64000
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Timestamp                    5533 non-null   object
#  1   Status-Hz[Hz]                5532 non-null   float64
#  2   Press-Pump Intake (Pi)[psi]  5532 non-null   float64
#  3   Temp-Motor[degF]             5532 non-null   float64
#  4   Vib-Pump X axis[G]           5532 non-null   float64
#  5   Vib-Pump Y axis[G]           5532 non-null   float64
#  6   Press-Pump Discharge[psi]    5532 non-null   float64
#  7   Pwr-Motor Amps Ph B[A]       5532 non-null   float64
#  8   Prod-Virtual % Water Cut[%]  5512 non-null   float64
#  9   Prod-Virtual GOR[SCF/STB]    5512 non-null   float64
#  10  Prod-Virtual Flow[BPD]       5533 non-null   float64
# dtypes: float64(10), object(1)
# memory usage: 518.7+ KB
